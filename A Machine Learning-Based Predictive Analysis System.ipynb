# %% [markdown]
# # Project Title: [WRITE YOUR PROJECT TITLE HERE]
#
# ## Project Track
# Machine Learning / Deep Learning / NLP / LLM (choose one)
#
# ## Problem Definition & Objective
#
# The objective of this project is to build an AI-based system that solves a real-world problem using data-driven techniques.
# This project focuses on analyzing data, training a predictive model, and evaluating its performance to generate meaningful insights and accurate results.
#
# ### Real-World Relevance
# This problem is relevant in real-world scenarios where automation, prediction, and intelligent decision-making are required to improve efficiency and accuracy.

# %%
# !pip install pandas_datareader
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------- -------------------------------- 0.8/4.0 MB 4.6 MB/s eta 0:00:01
#    ------------------ --------------------- 1.8/4.0 MB 4.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.9/4.0 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  3.9/4.0 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 4.7 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    -------------------- ------------------- 1/2 [pandas_datareader]
#    -------------------- ------------------- 1/2 [pandas_datareader]
#    ---------------------------------------- 2/2 [pandas_datareader]
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as data

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
# !pip install yfinance
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------------------- -------------- 1.0/1.6 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 5.4 MB/s  0:00:00
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15703 sha256=c291fcbb87cd58c2532931c69cb18987636525a9ef1d8e74840eea643ed6ba14
#   Stored in directory: c:\users\siri chandana\appdata\local\pip\cache\wheels\1e\df\0f\e2bbb22d689b30c681feb5410ab64a2523437b34c8ecfc6476
# Successfully built multitasking
# ...
#
#    ---------------------------------------- 0/5 [peewee]
#    ---------------------------------------- 0/5 [peewee]
#    ---------------- ----------------------- 2/5 [websockets]
#    ---------------- ----------------------- 2/5 [websockets]
#    ---------------- ----------------------- 2/5 [websockets]
# ...

# %%
import yfinance as yf
import datetime as dt

stock = "POWERGRID.NS"
start = dt.datetime(2000, 1, 1)
end = dt.datetime(2024, 11, 1)

df = yf.download(stock, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price             Close         High          Low         Open       Volume
# Ticker     POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS
# Date
# 2007-10-05    31.243088    34.007139    25.823685    27.888959    855215656
# 2007-10-08    29.643667    32.299019    29.457326    32.299019    126671715
# 2007-10-09    31.662342    31.941852    28.059761    29.659181    116725709
# 2007-10-10    31.957382    32.609574    31.677872    32.485346     67931378
# 2007-10-11    35.528904    37.268082    31.677871    37.268082    106320954

# %%
df.shape
# Out:
# (4208, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4208 entries, 2007-10-05 to 2024-10-31
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   (Close, POWERGRID.NS)   4208 non-null   float64
#  1   (High, POWERGRID.NS)    4208 non-null   float64
#  2   (Low, POWERGRID.NS)     4208 non-null   float64
#  3   (Open, POWERGRID.NS)    4208 non-null   float64
#  4   (Volume, POWERGRID.NS)  4208 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 197.2 KB

# %%
df.isnull().sum()
# Out:
# Price   Ticker
# Close   POWERGRID.NS    0
# High    POWERGRID.NS    0
# Low     POWERGRID.NS    0
# Open    POWERGRID.NS    0
# Volume  POWERGRID.NS    0
# dtype: int64

# %%
df.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS  POWERGRID.NS
# count   4208.000000  4208.000000  4208.000000  4208.000000  4.208000e+03
# mean      76.940540    77.940330    75.952691    76.976097  1.188963e+07
# std       62.451612    63.182031    61.673576    62.433572  2.061999e+07
# min       18.241358    19.499382    16.354321    19.405030  0.000000e+00
# 25%       35.067365    35.620614    34.549475    35.103278  4.799653e+06
# 50%       53.283848    53.899086    52.570761    53.386138  8.344398e+06
# 75%       79.787134    80.739490    78.841025    79.808833  1.362032e+07
# max      348.714508   349.477891   340.842311   347.378597  8.552157e+08

# %%
df = df.reset_index()

# %%
df.columns
# Out:
# MultiIndex([(  'Date',             ''),
#             ( 'Close', 'POWERGRID.NS'),
#             (  'High', 'POWERGRID.NS'),
#             (   'Low', 'POWERGRID.NS'),
#             (  'Open', 'POWERGRID.NS'),
#             ('Volume', 'POWERGRID.NS')],
#            names=['Price', 'Ticker'])

# %% [markdown]
# ## Data Understanding & Preparation
#
# ### Dataset Source
# The dataset used in this project is obtained from a publicly available source.
# It contains multiple features that are relevant to solving the defined problem.
#
# ### Data Overview
# In this step, the dataset is loaded and explored to understand:
# - Data shape and structure
# - Feature types
# - Presence of missing or inconsistent values

# %%
df.to_csv(r"C:\Users\Siri Chandana\Downloads\powergrid.csv")

# %%
data01 = pd.read_csv(r"C:\Users\Siri Chandana\Downloads\powergrid.csv")

# %%
data01.head()
# Out:
#     Price        Date               Close                High  \
# 0  Ticker         NaN        POWERGRID.NS        POWERGRID.NS
# 1       0  2007-10-05  31.243087768554688   34.00713890708205
# 2       1  2007-10-08  29.643667221069336   32.29901899181281
# 3       2  2007-10-09  31.662342071533203  31.941851779936375
# 4       3  2007-10-10  31.957382202148438  32.609574363390415
#
#                   Low                Open        Volume
# 0        POWERGRID.NS        POWERGRID.NS  POWERGRID.NS
# 1  25.823684924550964  27.888959409330344     855215656
# 2   29.45732593302171   32.29901899181281     126671715
# 3  28.059760795619255  29.659181438690247     116725709
# 4  31.677872479427172   32.48534618182709      67931378

# %%
# !pip install plotly
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 6.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.0/9.9 MB 2.3 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.3/9.9 MB 2.5 MB/s eta 0:00:04
#    ------- -------------------------------- 1.8/9.9 MB 2.3 MB/s eta 0:00:04
#    -------- ------------------------------- 2.1/9.9 MB 2.2 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.6/9.9 MB 2.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.9/9.9 MB 2.0 MB/s eta 0:00:04
#    ------------- -------------------------- 3.4/9.9 MB 2.0 MB/s eta 0:00:04
#    --------------- ------------------------ 3.9/9.9 MB 2.1 MB/s eta 0:00:03
#    ------------------ --------------------- 4.5/9.9 MB 2.1 MB/s eta 0:00:03
#    ------------------- -------------------- 4.7/9.9 MB 2.1 MB/s eta 0:00:03
# ...

# %%
# Candlesticks 
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x = data01['Date'], open = data01['Open'], 
                                    high = data01['High'],
                                    low = data01['Low'], 
                                    close = data01['Close'])])
fig.update_layout(xaxis_rangeslider_visible=False)
fig.show()

# %%
print(df.columns)
# Out:
# MultiIndex([(  'Date',             ''),
#             ( 'Close', 'POWERGRID.NS'),
#             (  'High', 'POWERGRID.NS'),
#             (   'Low', 'POWERGRID.NS'),
#             (  'Open', 'POWERGRID.NS'),
#             ('Volume', 'POWERGRID.NS')],
#            names=['Price', 'Ticker'])

# %%
# flatten multiindex to single level
df.columns = [col[0] for col in df.columns]

# optional: rename columns nicely
df.columns = ['Date', 'Close', 'High', 'Low', 'Open', 'Volume']

# drop Date if you don't need it
df = df.drop(['Date'], axis=1)

print(df.head())
# Out:
#        Close       High        Low       Open     Volume
# 0  31.243088  34.007139  25.823685  27.888959  855215656
# 1  29.643667  32.299019  29.457326  32.299019  126671715
# 2  31.662342  31.941852  28.059761  29.659181  116725709
# 3  31.957382  32.609574  31.677872  32.485346   67931378
# 4  35.528904  37.268082  31.677871  37.268082  106320954

# %%
df.head()
# Out:
#        Close       High        Low       Open     Volume
# 0  31.243088  34.007139  25.823685  27.888959  855215656
# 1  29.643667  32.299019  29.457326  32.299019  126671715
# 2  31.662342  31.941852  28.059761  29.659181  116725709
# 3  31.957382  32.609574  31.677872  32.485346   67931378
# 4  35.528904  37.268082  31.677871  37.268082  106320954

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Close'], label = f'{stock} Closing Price', linewidth = 1)
plt.title(f'{stock} Closing prices over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Open'], label = f'{stock} Opening Price', linewidth = 1)
plt.title(f'{stock} Opening prices over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['High'], label = f'{stock} High Price', linewidth = 1)
plt.title(f'{stock} High prices over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Volume'], label = f'{stock} Volume', linewidth = 2)
plt.title(f'{stock} Volume over time')
plt.legend()
plt.show()

# %%
# Moving Average
# [10, 20, 30, 40, 50, 60, 70, 80, 90]
# moving average for last 5 days -> null null null null 30.0 40.0 50.0

temp_data = [10, 20, 30, 40, 50, 60, 70, 80, 90]
print(sum(temp_data[2:7])/5)
# Out:
# 50.0

# %%
import pandas as pd
df01 = pd.DataFrame(temp_data)

# %%
df01.rolling(5).mean()
# Out:
#       0
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4  30.0
# 5  40.0
# 6  50.0
# 7  60.0
# 8  70.0

# %%
ma100 = df.Close.rolling(100).mean()

# %%
ma100
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 4203    318.240850
# 4204    318.477401
# 4205    318.708451
# 4206    318.903848
# 4207    319.037445
# Name: Close, Length: 4208, dtype: float64

# %%
ma200 = df.Close.rolling(200).mean()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label = f'{stock} Close Price', linewidth = 1)
plt.plot(ma100, label = f'{stock} Moving Average 100 Price', linewidth = 1)
plt.plot(ma200, label = f'{stock} Moving Average 200 Price', linewidth = 1)
plt.legend()
plt.show()

# %%
ema100 = df.Close.ewm(span=100, adjust = False).mean()

# %%
ema200 = df['Close'].ewm(span=200, adjust = False).mean()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label = f'{stock} Close Price', linewidth = 1)
plt.plot(ema100, label = f'{stock} Exp. Moving Average 100 Price', linewidth = 1)
plt.plot(ema200, label = f'{stock} Exp. Moving Average 200 Price', linewidth = 1)
plt.legend()
plt.show()

# %%
# Training & Testing

data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70): int(len(df))])

# %%
data_training.shape
# Out:
# (2945, 1)

# %%
data_testing.shape
# Out:
# (1263, 1)

# %% [markdown]
# ### Data Preprocessing
#
# Feature scaling is applied using MinMaxScaler to normalize numerical features between 0 and 1.
# This helps improve model convergence and ensures uniform feature contribution.

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (0, 1))

# %%
data_training_array = scaler.fit_transform(data_training)

# %%
data_training_array
# Out:
# array([[0.19808612],
#        [0.17371836],
#        [0.20447361],
#        ...,
#        [0.90774416],
#        [0.86000369],
#        [0.8729965 ]], shape=(2945, 1))

# %%
data_training_array.shape[0]
# Out:
# 2945

# %% [markdown]
# ### Feature Selection & Data Splitting
#
# Relevant features are selected, and the dataset is split into training and testing sets to evaluate model performance on unseen data.

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i, 0])

x_train, y_train  = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (2845, 100, 1)

# %%
import warnings
warnings.filterwarnings("ignore")

from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential

# %% [markdown]
# ## Model / System Design
#
# ### AI Technique Used
# This project uses a Machine Learning algorithm to learn patterns from the data and make predictions.
#
# ### Model Justification
# The chosen model is suitable due to its effectiveness, interpretability, and performance on structured data.

# %%
model = Sequential()

model.add(LSTM(units = 50, activation = 'relu', return_sequences = True, input_shape = (x_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
model.add(Dropout(0.3))

model.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
model.add(Dropout(0.4))

model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 1))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                        │ (None, 100, 50)             │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 100, 50)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_5 (LSTM)                        │ (None, 100, 60)             │          26,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 100, 60)             │               0 │
# ...

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(x_train, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 21s 146ms/step - loss: 0.0442
# Epoch 2/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 158ms/step - loss: 0.0089
# Epoch 3/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 158ms/step - loss: 0.0079
# Epoch 4/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 156ms/step - loss: 0.0076
# Epoch 5/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 156ms/step - loss: 0.0066
# Epoch 6/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 157ms/step - loss: 0.0061
# Epoch 7/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 160ms/step - loss: 0.0059
# Epoch 8/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 159ms/step - loss: 0.0054
# Epoch 9/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 159ms/step - loss: 0.0058
# Epoch 10/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 158ms/step - loss: 0.0049
# Epoch 11/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 155ms/step - loss: 0.0045
# Epoch 12/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 155ms/step - loss: 0.0051
# Epoch 13/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 160ms/step - loss: 0.0044
# Epoch 14/50
# ...

# %%
past_100_days = data_training.tail(100)

# %%
import pandas as pd
final_df = pd.concat([past_100_days, data_testing], ignore_index=True)

# %%
final_df.head()
# Out:
#        Close
# 0  73.060181
# 1  74.549599
# 2  74.804375
# 3  74.647598
# 4  75.078751

# %%
input_data = scaler.fit_transform(final_df)

# %%
x_test = []
y_test = []

for i in range(100, input_data.shape[0]):
    x_test.append(input_data[i-100:i])
    y_test.append(input_data[i, 0])

x_test, y_test  = np.array(x_test), np.array(y_test)

# %%
x_test.shape
# Out:
# (1263, 100, 1)

# %% [markdown]
# ## Core Implementation
#
# This section covers the end-to-end implementation, including model training and prediction on test data.

# %%
y_predicted = model.predict(x_test)
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step

# %%
y_predicted.shape
# Out:
# (1263, 1)

# %%
scaler.scale_
# Out:
# array([0.00345503])

# %%
scaler_factor = 1 / 0.0035166
y_predicted = y_predicted * scaler_factor
y_test = y_test * scaler_factor

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test, label = 'Original Price', linewidth = 1)
plt.plot(y_predicted, label = 'Predicted Price', linewidth = 1)
plt.legend()
plt.show()

# %%
model.save("stock_model.keras")

# %% [markdown]
# ## Ethical Considerations & Responsible AI
#
# - Potential bias in the dataset may affect predictions.
# - Results should be interpreted responsibly.
# - The system should not be used for critical decisions without validation.
#
# ## Conclusion & Future Scope
#
# ### Conclusion
# The project successfully demonstrates an AI-based solution for the given problem.
#
# ### Future Scope
# - Improve accuracy using advanced models
# - Use larger datasets
# - Deploy as a web application
